# %% [markdown]
# ## Import & Pathing (local)
# Requires that you have unzipped the raw_data.zip to a folder called 'data'

# %%
# Pathing Libraries
from pathlib import Path
import os
import os.path as op
import glob

# Image Libraries
import nibabel as nib
import numpy as np
from scipy import stats
import imageio as iio
import scipy.ndimage as ndi
import matplotlib.pyplot as plt

# %%
# Pathing
path = '../'

images_path = Path(path, 'data', 'images')
masks_path = Path(path, 'data', 'masks')
segs_path = Path(path, 'data', 'segs_refs')
metadata_path = Path(path, 'data', 'metadata')

# %% [markdown]
# ### Image testing w/ nibabel

# %%
image = nib.load(op.join(images_path, 'sub-CC110033_T1w_unbiased' + '.nii.gz'))
img_data = image.get_fdata()
img_data.shape

## Plot testing
fig_rows = 4
fig_cols = 4
n_subplots = fig_rows * fig_cols
n_slice = img_data.shape[0]
step_size = n_slice // n_subplots
plot_range = n_subplots * step_size
start_stop = int((n_slice - plot_range) / 2)

fig, axs = plt.subplots(fig_rows, fig_cols, figsize=[10, 10])

for idx, img in enumerate(range(start_stop, plot_range, step_size)):
    axs.flat[idx].imshow(ndi.rotate(img_data[img, :, :], 90), cmap='viridis')
    axs.flat[idx].axis('off')
        
plt.tight_layout()
plt.show()

# %%
image = nib.load(op.join(segs_path, 'sub-CC110033_T1w' + '_seg' + '.nii.gz'))
img_data = image.get_fdata()
img_data = stats.zscore(img_data, axis=None)

## Plot testing
fig_rows = 4
fig_cols = 4
n_subplots = fig_rows * fig_cols
n_slice = img_data.shape[0]
step_size = n_slice // n_subplots
plot_range = n_subplots * step_size
start_stop = int((n_slice - plot_range) / 2)

fig, axs = plt.subplots(fig_rows, fig_cols, figsize=[10, 10])

for idx, img in enumerate(range(start_stop, plot_range, step_size)):
    axs.flat[idx].imshow(ndi.rotate(img_data[img, :, :], 90), cmap='viridis')
    axs.flat[idx].axis('off')
        
plt.tight_layout()
plt.show()
